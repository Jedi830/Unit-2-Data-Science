# %%
print("Hello my world")
# Out:
# Hello my world

# %% [markdown]
# HELLO PYTHON, IT IS FUN TO CODE WITH YOU AGAIN. I HOPE I LEARN SOME NEW THINGS WITH YOU THIS TIME, HOPEFULLY I REMEMBER THEM!!!!!!!!!

# %%
import matplotlib.pyplot as plt

js_ylist = [1,2,3,4]

js_xlist = [22,87,0,18]

plt.plot(js_xlist,js_ylist)

plt.ylabel("Memes")
plt.xlabel("Derp")
plt.title("THAT graph")
# Out:
# Text(0.5, 1.0, 'THAT graph')

# %%
height = [2,4,6,8,10]
x = [4,8,12,16,20]
plt.bar(x,height)
plt.xlabel("Number of songs")
plt.ylabel("Likeablity")
plt.title("Songs I listen to on a daily")
# Out:
# Text(0.5, 1.0, 'Songs I listen to on a daily')

# %%
games = ["Diablo 4, Fortnite, Brawlhalla"]
Likeablity = [2,4,7]


fig = plt.figure(figsize=(10,7))
plt.pie(data, labels = games)

plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       2 Likeablity = [2,4,7]
#       5 fig = plt.figure(figsize=(10,7))
# ----> 6 plt.pie(data, labels = games)
#       8 plt.show
#
# NameError: name 'data' is not defined
